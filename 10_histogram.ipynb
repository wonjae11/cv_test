# %% [markdown]
# ## 10. 히스토그램

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlibNote: you may need to restart the kernel to use updated packages.
#
#   Downloading matplotlib-3.10.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.55.3-cp313-cp313-win_amd64.whl.metadata (168 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\admin\documents\opencvprac\my_cv\lib\site-packages (from matplotlib) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\documents\opencvprac\my_cv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\admin\documents\opencvprac\my_cv\lib\site-packages (from matplotlib) (11.1.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\documents\opencvprac\my_cv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\documents\opencvprac\my_cv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.0-cp313-cp313-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 8.0/8.0 MB 41.0 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp313-cp313-win_amd64.whl (220 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.3-cp313-cp313-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 41.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.3 kiwisolver-1.4.8 matplotlib-3.10.0 pyparsing-3.2.1

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("images/winter.jpg")
# channel : 0 - blue/1 - green/2 - red
hist_b = cv2.calcHist([img], [0], None, [256], [0, 256])
hist_g = cv2.calcHist([img], [1], None, [256], [0, 256])
hist_r = cv2.calcHist([img], [2], None, [256], [0, 256])

plt.plot(hist_b, color = "b")
plt.plot(hist_g, color = "g")
plt.plot(hist_r, color = "r")
plt.title("histogram")
plt.xlabel("Pixel value")
plt.ylabel("Frequency")
plt.show()
